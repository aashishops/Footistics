# %% [markdown]
# # Shot Heatmaps Top 10 goalscorers in EPL

# %% [markdown]
# ## Libraries to import

# %%
# Import libraries:
import json
import pandas as pd
from copy import deepcopy
from bs4 import BeautifulSoup
from urllib.request import urlopen

# Import plotting libraries:
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
from matplotlib.patches import Arc

# %% [markdown]
# ## Create field image

# %%
# Setting boundaries and midpoint:
x_lims = [0, 1.15]
y_lims = [0, 0.74]

x_mid = x_lims[1]/2
y_mid = y_lims[1]/2

# Setting color and linewidth:
background_color = "#1B1B1A"
line_color = "white"
line_width = 2.

# %% [markdown]
# NOTE: [Definition of a Function in Python](https://www.w3schools.com/python/python_functions.asp)

# %% [markdown]
# ## Heatmap - Top goal goalscorer

# %% [markdown]
# ### Scrape data for top goalscorer
# Source --> [Understat website](https://understat.com/)

# %%
#selecting europe's Top 5 leagues
leagues = ['EPL/2022','La_liga/2022','Bundesliga/2022','Ligue_1/2022','Serie_A/2022']

# %%
#extracting all players id from the leagues
player_id_list =[]
final_jsonfinal_df= pd.DataFrame()
for i in leagues:
  scrape_url = "https://understat.com/league/{}".format(i)
  page_connect = urlopen(scrape_url)
  page_html = BeautifulSoup(page_connect, "html.parser")
  json_raw_string = page_html.findAll(name="script")[3].text
  start_ind = json_raw_string.index("\\")
  stop_ind = json_raw_string.index("')")
  json_data = json_raw_string[start_ind:stop_ind]
  json_data = json_data.encode("utf8").decode("unicode_escape")
  final_json_df = pd.json_normalize(json.loads(json_data))
  final_jsonfinal_df = pd.concat([final_jsonfinal_df, final_json_df], ignore_index=True)

player_id_list = final_jsonfinal_df["id"].to_list()
print(player_id_list)
# Out:
# ['8260', '647', '998', '1250', '468', '556', '2517', '7752', '8865', '773', '7322', '2381', '6681', '482', '5543', '6055', '7420', '453', '5232', '6818', '7814', '8379', '8706', '239', '843', '6552', '10720', '10846', '314', '986', '1228', '7698', '10760', '204', '447', '522', '5220', '5786', '6034', '6756', '6854', '10806', '11296', '87', '501', '553', '618', '1679', '1776', '3585', '6049', '6122', '6345', '6853', '8291', '8941', '10177', '531', '620', '675', '700', '750', '1726', '2182', '2203', '3697', '6108', '6857', '7166', '7395', '7700', '8720', '10741', '10804', '10866', '343', '672', '762', '822', '922', '2248', '3635', '5221', '5553', '6063', '6482', '6827', '7365', '7892', '8150', '8327', '9492', '9738', '10405', '10408', '10716', '10743', '11058', '11094', '11297', '755', '757', '833', '910', '1654', '2328', '2335', '4456', '5613', '5956', '6253', '6492', '6630', '6665', '6912', '7768', '8845', '9040', '9678', '9680', '10552', '10715', '10746', '10750', '11317', '486', '500', '503', '586', '643', '660', '695', '782', '900', '935', '1376', '1389', '1791', '2379', '2496', '4419', '5555', '5595', '5596', '5735', '6157', '6500', '6521', '6691', '6817', '6835', '6837', '6888', '6893', '6935', '7080', '7298', '7430', '8288', '8716', '8717', '9301', '9501', '9630', '9739', '9892', '9948', '10766', '10864', '11155', '76', '101', '318', '332', '448', '488', '510', '530', '532', '535', '579', '585', '631', '646', '652', '753', '802', '804', '885', '966', '1006', '1024', '1234', '1245', '1653', '1665', '1749', '1785', '1801', '1823', '2199', '2254', '2280', '2371', '2662', '2958', '3203', '3293', '3303', '3600', '3621', '5086', '5136', '5264', '5560', '5590', '5602', '5682', '5973', '6026', '6048', '6088', '6104', '6252', '6314', '6485', '6674', '6851', '6852', '6894', '7007', '7078', '7083', '7184', '7198', '7240', '7281', '7382', '7546', '7589', '7603', '7723', '8066', '8067', '8204', '8384', '8582', '8646', '8780', '8816', '8970', '9453', '9493', '9662', '9667', '10004', '10012', '10293', '10536', '10723', '10744', '10751', '10756', '10759', '10802', '11000', '11007', '11357', '11362', '11363', '11384', '181', '229', '458', '461', '463', '473', '489', '496', '508', '509', '528', '534', '546', '558', '561', '584', '603', '605', '633', '635', '637', '638', '645', '661', '668', '681', '688', '694', '706', '713', '741', '751', '759', '766', '767', '769', '770', '790', '807', '813', '825', '831', '842', '847', '884', '978', '983', '985', '987', '1042', '1078', '1257', '1297', '1299', '1488', '1537', '1545', '1677', '1683', '1687', '1688', '1711', '1719', '1735', '1750', '1789', '2163', '2190', '2243', '2245', '2310', '2498', '2674', '3278', '3288', '3298', '3420', '3422', '3696', '4105', '4120', '4381', '4401', '5050', '5061', '5247', '5248', '5360', '5545', '5549', '5552', '5584', '5603', '5609', '5646', '5712', '5789', '5989', '6027', '6030', '6042', '6047', '6054', '6080', '6083', '6147', '6163', '6249', '6273', '6310', '6326', '6329', '6382', '6424', '6490', '6532', '6615', '6656', '6736', '6820', '6840', '6850', '6856', '6880', '6891', '6923', '6937', '6962', '6986', '7052', '7069', '7134', '7218', '7230', '7235', '7236', '7239', '7280', '7282', '7332', '7338', '7352', '7366', '7384', '7438', '7582', '7689', '7691', '7699', '7701', '7702', '7726', '7753', '7823', '7891', '7904', '7921', '7931', '7988', '8089', '8090', '8119', '8214', '8222', '8226', '8228', '8430', '8458', '8497', '8562', '8635', '8666', '8704', '8715', '8719', '8786', '8812', '8821', '8852', '8859', '8864', '8940', '8942', '8961', '8965', '8992', '9021', '9098', '9154', '9156', '9274', '9324', '9339', '9356', '9470', '9499', '9512', '9524', '9552', '9676', '9677', '9679', '9681', '9683', '9685', '9686', '9689', '9710', '9733', '9734', '9740', '9741', '9912', '9914', '10036', '10072', '10140', '10168', '10216', '10291', '10292', '10348', '10453', '10579', '10698', '10718', '10719', '10740', '10742', '10745', '10749', '10752', '10753', '10755', '10757', '10 ...

# %%
player_shot_df_list = []
for p_id in player_id_list:
    # Scrape player stats:
    scrape_url = "https://understat.com/player/{}".format(p_id)
    page_connect = urlopen(scrape_url)
    page_html = BeautifulSoup(page_connect, "html.parser")

    json_raw_string = page_html.findAll(name="script")[3].text
    start_ind = json_raw_string.index("\\")
    stop_ind = json_raw_string.index("')")

    json_data = json_raw_string[start_ind:stop_ind]
    json_data = json_data.encode("utf8").decode("unicode_escape")

    shots_df = pd.json_normalize(json.loads(json_data))
    shots_df = shots_df.apply(pd.to_numeric, errors="ignore")

    full_pitch_shots_df = deepcopy(shots_df)

    player_shot_df_list.append(full_pitch_shots_df)

# %%
player_shots = pd.concat(player_shot_df_list, ignore_index=True)
player_shots2022_2023 =player_shots[player_shots['season']==2022]

# %%
player_shots2022_2023.columns
# Out:
# Index(['id', 'minute', 'result', 'X', 'Y', 'xG', 'player', 'h_a', 'player_id',
#        'situation', 'season', 'shotType', 'match_id', 'h_team', 'a_team',
#        'h_goals', 'a_goals', 'date', 'player_assisted', 'lastAction'],
#       dtype='object')

# %%
player_shots2022_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47653 entries, 205 to 275330
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               47653 non-null  int64
#  1   minute           47653 non-null  int64
#  2   result           47653 non-null  object
#  3   X                47653 non-null  float64
#  4   Y                47653 non-null  float64
#  5   xG               47653 non-null  float64
#  6   player           47653 non-null  object
#  7   h_a              47653 non-null  object
#  8   player_id        47653 non-null  int64
#  9   situation        47653 non-null  object
#  10  season           47653 non-null  int64
#  11  shotType         47653 non-null  object
#  12  match_id         47653 non-null  int64
#  13  h_team           47653 non-null  object
#  14  a_team           47653 non-null  object
#  15  h_goals          47653 non-null  int64
#  16  a_goals          47653 non-null  int64
#  17  date             47653 non-null  object
#  18  player_assisted  35211 non-null  object
#  19  lastAction       47653 non-null  object
# dtypes: float64(3), int64(7), object(10)
# memory usage: 7.6+ MB

# %%
player_shots2022_2023.shape
# Out:
# (47653, 20)

# %%
player_shots2022_2023.apply(pd.to_numeric, errors="ignore").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47653 entries, 205 to 275330
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               47653 non-null  int64
#  1   minute           47653 non-null  int64
#  2   result           47653 non-null  object
#  3   X                47653 non-null  float64
#  4   Y                47653 non-null  float64
#  5   xG               47653 non-null  float64
#  6   player           47653 non-null  object
#  7   h_a              47653 non-null  object
#  8   player_id        47653 non-null  int64
#  9   situation        47653 non-null  object
#  10  season           47653 non-null  int64
#  11  shotType         47653 non-null  object
#  12  match_id         47653 non-null  int64
#  13  h_team           47653 non-null  object
#  14  a_team           47653 non-null  object
#  15  h_goals          47653 non-null  int64
#  16  a_goals          47653 non-null  int64
#  17  date             47653 non-null  object
#  18  player_assisted  35211 non-null  object
#  19  lastAction       47653 non-null  object
# dtypes: float64(3), int64(7), object(10)
# memory usage: 7.6+ MB

# %%
player_shots2022_2023= player_shots2022_2023.apply(pd.to_numeric, errors="ignore")

# %%
player_shots2022_2023.describe().round(1)
# Out:
#              id   minute        X        Y       xG  player_id   season  \
# count   47653.0  47653.0  47653.0  47653.0  47653.0    47653.0  47653.0
# mean   505495.7     48.9      0.9      0.5      0.1     5820.8   2022.0
# std     14753.7     26.7      0.1      0.1      0.2     3463.1      0.0
# min    478469.0      0.0      0.0      0.0      0.0        3.0   2022.0
# 25%    493134.0     27.0      0.8      0.4      0.0     2356.0   2022.0
# 50%    505676.0     49.0      0.9      0.5      0.1     6421.0   2022.0
# 75%    517991.0     71.0      0.9      0.6      0.1     8696.0   2022.0
# max    531291.0    105.0      1.0      1.0      1.0    11627.0   2022.0
#
#        match_id  h_goals  a_goals
# count   47653.0  47653.0  47653.0
# mean    19109.0      1.6      1.3
# std       527.2      1.4      1.1
# min     18202.0      0.0      0.0
# 25%     18647.0      1.0      0.0
# 50%     19108.0      1.0      1.0
# 75%     19567.0      2.0      2.0
# max     20159.0      9.0      7.0

# %%
player_shots2022_2023.head(10)
# Out:
#          id  minute       result      X      Y        xG          player h_a  \
# 205  479846      20  MissedShots  0.936  0.503  0.484085  Erling Haaland   a
# 206  479847      35         Goal  0.885  0.500  0.761169  Erling Haaland   a
# 207  479854      64         Goal  0.864  0.405  0.328053  Erling Haaland   a
# 208  479855      69  MissedShots  0.953  0.552  0.526608  Erling Haaland   a
# 209  479856      75  BlockedShot  0.894  0.710  0.066443  Erling Haaland   a
# 210  480318      44    SavedShot  0.933  0.707  0.084546  Erling Haaland   h
# 211  480325      72  MissedShots  0.905  0.575  0.136635  Erling Haaland   h
# 212  482576      51    SavedShot  0.822  0.606  0.055626  Erling Haaland   a
# 213  482581      59         Goal  0.967  0.567  0.541526  Erling Haaland   a
# 214  482582      61    SavedShot  0.866  0.443  0.339789  Erling Haaland   a
#
#      player_id   situation  season   shotType  match_id            h_team  \
# 205       8260    OpenPlay    2022       Head     18211          West Ham
# 206       8260     Penalty    2022   LeftFoot     18211          West Ham
# 207       8260    OpenPlay    2022   LeftFoot     18211          West Ham
# 208       8260    OpenPlay    2022       Head     18211          West Ham
# 209       8260    OpenPlay    2022   LeftFoot     18211          West Ham
# 210       8260    OpenPlay    2022   LeftFoot     18214   Manchester City
# 211       8260    OpenPlay    2022   LeftFoot     18214   Manchester City
# 212       8260    OpenPlay    2022  RightFoot     18230  Newcastle United
# 213       8260  FromCorner    2022   LeftFoot     18230  Newcastle United
# 214       8260    OpenPlay    2022   LeftFoot     18230  Newcastle United
#
#               a_team  h_goals  a_goals                 date  player_assisted  \
# 205  Manchester City        0        2  2022-08-07 15:30:00       Phil Foden
# 206  Manchester City        0        2  2022-08-07 15:30:00             None
# 207  Manchester City        0        2  2022-08-07 15:30:00  Kevin De Bruyne
# 208  Manchester City        0        2  2022-08-07 15:30:00    Jack Grealish
# 209  Manchester City        0        2  2022-08-07 15:30:00   Ilkay Gündogan
# 210      Bournemouth        4        0  2022-08-13 14:00:00     João Cancelo
# 211      Bournemouth        4        0  2022-08-13 14:00:00    Jack Grealish
# 212  Manchester City        3        3  2022-08-21 15:30:00       Rúben Dias
# 213  Manchester City        3        3  2022-08-21 15:30:00            Rodri
# 214  Manchester City        3        3  2022-08-21 15:30:00  Kevin De Bruyne
#
#       lastAction
# 205        Cross
# 206     Standard
# 207  Throughball
# 208      Chipped
# 209         Pass
# 210      Chipped
# 211         Pass
# 212       TakeOn
# 213         Pass
# 214  Throughball

# %% [markdown]
# ### How to build a simple heatmap?

# %% [markdown]
# ### Heatmap with football field integrated

# %%
player_shots2022_2023.to_csv("Shots.csv")
